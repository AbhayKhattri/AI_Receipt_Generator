# %%
# !pip install pandas spacy rapidfuzz
# !python -m spacy download en_core_web_sm
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# Requirement already satisfied: pandas in c:\users\khatt\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: spacy in c:\users\khatt\anaconda3\lib\site-packages (3.8.5)
# Requirement already satisfied: rapidfuzz in c:\users\khatt\anaconda3\lib\site-packages (3.13.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\khatt\anaconda3\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khatt\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khatt\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khatt\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (2.11.1)
# Requirement already satisfied: jinja2 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\khatt\anaconda3\lib\site-packages (from spacy) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in c:\users\khatt\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\khatt\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\khatt\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\khatt\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\khatt\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\khatt\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khatt\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khatt\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khatt\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khatt\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: cloudpickle>=2.2.0 in c:\users\khatt\anaconda3\lib\site-packages (from srsly<3.0.0,>=2.4.3->spacy) (2.2.1)
# Requirement already satisfied: ujson>=1.35 in c:\users\khatt\anaconda3\lib\site-packages (from srsly<3.0.0,>=2.4.3->spacy) (5.4.0)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\khatt\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\khatt\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\khatt\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\khatt\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\khatt\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.13.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\khatt\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\khatt\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\khatt\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.2/12.8 MB 5.0 MB/s eta 0:00:03
#      -- ------------------------------------- 0.7/12.8 MB 9.3 MB/s eta 0:00:02
#      -- ------------------------------------- 0.9/12.8 MB 7.3 MB/s eta 0:00:02
#      --- ------------------------------------ 1.1/12.8 MB 6.3 MB/s eta 0:00:02
#      --- ------------------------------------ 1.2/12.8 MB 6.2 MB/s eta 0:00:02
#      --- ------------------------------------ 1.2/12.8 MB 6.2 MB/s eta 0:00:02
#      --- ------------------------------------ 1.2/12.8 MB 3.7 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.8/12.8 MB 5.1 MB/s eta 0:00:03
#      ------ --------------------------------- 2.0/12.8 MB 5.0 MB/s eta 0:00:03
#      ------ --------------------------------- 2.2/12.8 MB 4.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 4.7 MB/s eta 0:00:03
#      -------- ------------------------------- 2.6/12.8 MB 4.6 MB/s eta 0:00:03
#      -------- ------------------------------- 2.8/12.8 MB 4.7 MB/s eta 0:00:03
#      --------- ------------------------------ 2.9/12.8 MB 4.6 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.8 MB 4.5 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.3/12.8 MB 4.5 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.5/12.8 MB 4.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.7/12.8 MB 4.4 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 4.4 MB/s eta 0:00:03
#      ------------ --------------------------- 4.1/12.8 MB 4.3 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.8 MB 4.3 MB/s eta 0:00:02
#      ------------- -------------------------- 4.4/12.8 MB 4.3 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 4.3 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 4.3 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 4.3 MB/s eta 0:00:02
#      --------------- ------------------------ 4.8/12.8 MB 4.0 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.4/12.8 MB 4.2 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 4.2 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.7/12.8 MB 4.2 MB/s eta 0:00:02
#      ------------------ --------------------- 5.9/12.8 MB 4.2 MB/s eta 0:00:02
#      ------------------ --------------------- 6.1/12.8 MB 4.2 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.8 MB 4.2 MB/s eta 0:00:02
#      -------------------- ------------------- 6.5/12.8 MB 4.2 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/12.8 MB 4.2 MB/s eta 0:00:02
#      --------------------- ------------------ 6.8/12.8 MB 4.2 MB/s eta 0:00:02
#      --------------------- ------------------ 7.0/12.8 MB 4.2 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.2/12.8 MB 4.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.4/12.8 MB 4.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 4.2 MB/s eta 0:00:02
#      ------------------------ --------------- 7.7/12.8 MB 4.1 MB/s eta 0:00:02
#      ------------------------ --------------- 7.9/12.8 MB 4.1 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 4.1 MB/s eta 0:00:02
#      ------------------------- -------------- 8.3/12.8 MB 4.1 MB/s eta 0:00:02
#      -------------------------- ------------- 8.5/12.8 MB 4.1 MB/s eta 0:00:02
#      --------------------------- ------------ 8.7/12.8 MB 4.1 MB/s eta 0:00:02
#      --------------------------- ------------ 8.8/12.8 MB 4.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.0/12.8 MB 4.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 4.1 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.8 MB 4.1 MB/s eta 0:00:01
#      ------------------------------ --------- 9.6/12.8 MB 4.1 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.8 MB 4.1 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 4.1 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 4.1 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.8 MB 4.1 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 4.0 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.9/12.8 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.8 MB 3.9 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.8 MB 3.9 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.4/12.8 MB 4.1 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 3.9 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 3.9 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  12.5/12.8 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.8 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Requirement already satisfied: fuzzywuzzy in c:\users\khatt\anaconda3\lib\site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in c:\users\khatt\anaconda3\lib\site-packages (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\khatt\anaconda3\lib\site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\khatt\anaconda3\lib\site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.13.0)

# %%
import pandas as pd
from fuzzywuzzy import process

# Load dataset
df = pd.read_csv("C:/Users/khatt/OneDrive - DIT University/Desktop/recipe_df.csv")
df.rename(columns={'title': 'Dish', 'ingredients': 'Ingredients', 'directions': 'Steps'}, inplace=True)

def find_best_matches(user_input, df, top_n=3):
    """
    Finds the best matching dishes from the dataset.
    """
    exact_match = df[df['Dish'].str.lower() == user_input.lower()]
    
    if not exact_match.empty:
        return exact_match.iloc[0]
    
    matches = process.extract(user_input, df['Dish'], limit=top_n)
    return [df[df['Dish'] == match[0]].iloc[0] for match in matches]

# Get user input
user_dish = input("Enter your dish name: ")
matched_recipes = find_best_matches(user_dish, df)

if isinstance(matched_recipes, pd.Series):
    print(f"\n🍽️ **Best match found: {matched_recipes['Dish']}**")
    print(f"\n🥘 **Ingredients:** {matched_recipes['Ingredients']}")
    print(f"\n📜 **Steps:** {matched_recipes['Steps']}")
else:
    print("\nSorry, exact match not found. Did you mean one of these?")
    for recipe in matched_recipes:
        print(f"- {recipe['Dish']}")
